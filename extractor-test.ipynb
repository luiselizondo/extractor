# %% [markdown]
# # Extract a PDF using ML

# %%
# %reload_ext autoreload
# %autoreload 2

import sys

sys.path.append(".")
sys.path.append("..")
sys.path.append("../..")

# %%
# !{sys.executable} -m pip install nougat-ocr transformers datasets
# Out:
# Collecting uniflow
#   Using cached uniflow-0.0.31-py3-none-any.whl.metadata (18 kB)
# Collecting nougat-ocr
#   Using cached nougat_ocr-0.1.17-py3-none-any.whl.metadata (10 kB)
# Collecting transformers
#   Using cached transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
# Collecting datasets
#   Using cached datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting graphviz<0.21.0,>=0.20.1 (from uniflow)
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting openai<2.0.0,>=1.2.4 (from uniflow)
#   Downloading openai-1.35.11-py3-none-any.whl.metadata (21 kB)
# Collecting pydantic<3.0.0,>=2.5.2 (from uniflow)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from uniflow)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting tiktoken<0.7.0,>=0.6.0 (from uniflow)
#   Using cached tiktoken-0.6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting timm==0.5.4 (from nougat-ocr)
#   Using cached timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# Collecting orjson (from nougat-ocr)
#   Using cached orjson-3.10.6-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
# Collecting opencv-python-headless (from nougat-ocr)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting lightning<2022,>=2.0.0 (from nougat-ocr)
#   Using cached lightning-2.3.3-py3-none-any.whl.metadata (35 kB)
# Collecting nltk (from nougat-ocr)
#   Using cached nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting python-Levenshtein (from nougat-ocr)
#   Using cached python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting sentencepiece (from nougat-ocr)
#   Using cached sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting sconf>=0.2.3 (from nougat-ocr)
#   Using cached sconf-0.2.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting albumentations>=1.0.0 (from nougat-ocr)
#   Using cached albumentations-1.4.11-py3-none-any.whl.metadata (39 kB)
# Collecting pypdf>=3.1.0 (from nougat-ocr)
#   Using cached pypdf-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pypdfium2 (from nougat-ocr)
#   Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting torch>=1.4 (from timm==0.5.4->nougat-ocr)
#   Downloading torch-2.3.1-cp312-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting torchvision (from timm==0.5.4->nougat-ocr)
#   Downloading torchvision-0.18.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting filelock (from transformers)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Collecting numpy<2.0,>=1.17 (from transformers)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.0 MB/s eta 0:00:001.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/extractor/lib/python3.12/site-packages (from transformers) (24.1)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets)
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Using cached aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting scipy>=1.10.0 (from albumentations>=1.0.0->nougat-ocr)
#   Using cached scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting scikit-image>=0.21.0 (from albumentations>=1.0.0->nougat-ocr)
#   Using cached scikit_image-0.24.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting typing-extensions>=4.9.0 (from albumentations>=1.0.0->nougat-ocr)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting scikit-learn>=1.3.2 (from albumentations>=1.0.0->nougat-ocr)
#   Using cached scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (12 kB)
# Collecting albucore>=0.0.11 (from albumentations>=1.0.0->nougat-ocr)
#   Using cached albucore-0.0.12-py3-none-any.whl.metadata (3.1 kB)
# Collecting eval-type-backport (from albumentations>=1.0.0->nougat-ocr)
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning<2022,>=2.0.0->nougat-ocr)
#   Using cached lightning_utilities-0.11.3.post0-py3-none-any.whl.metadata (4.7 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning<2022,>=2.0.0->nougat-ocr)
#   Using cached torchmetrics-1.4.0.post0-py3-none-any.whl.metadata (19 kB)
# Collecting pytorch-lightning (from lightning<2022,>=2.0.0->nougat-ocr)
#   Using cached pytorch_lightning-2.3.3-py3-none-any.whl.metadata (21 kB)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.2.4->uniflow)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.2.4->uniflow)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.2.4->uniflow)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai<2.0.0,>=1.2.4->uniflow)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3.0.0,>=2.5.2->uniflow)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3.0.0,>=2.5.2->uniflow)
#   Using cached pydantic_core-2.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->transformers)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting ruamel.yaml (from sconf>=0.2.3->nougat-ocr)
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting munch (from sconf>=0.2.3->nougat-ocr)
#   Using cached munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting Pillow>=9.4.0 (from datasets[vision]->nougat-ocr)
#   Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting click (from nltk->nougat-ocr)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk->nougat-ocr)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/extractor/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->nougat-ocr)
#   Using cached Levenshtein-0.25.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->nougat-ocr)
#   Using cached rapidfuzz-3.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting tomli>=2.0.1 (from albucore>=0.0.11->albumentations>=1.0.0->nougat-ocr)
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.2.4->uniflow)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.2.4->uniflow)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/extractor/lib/python3.12/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning<2022,>=2.0.0->nougat-ocr) (69.5.1)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/extractor/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting networkx>=2.8 (from scikit-image>=0.21.0->albumentations>=1.0.0->nougat-ocr)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting imageio>=2.33 (from scikit-image>=0.21.0->albumentations>=1.0.0->nougat-ocr)
#   Using cached imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.21.0->albumentations>=1.0.0->nougat-ocr)
#   Using cached tifffile-2024.7.2-py3-none-any.whl.metadata (30 kB)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.21.0->albumentations>=1.0.0->nougat-ocr)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.2->albumentations>=1.0.0->nougat-ocr)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting sympy (from torch>=1.4->timm==0.5.4->nougat-ocr)
#   Using cached sympy-1.13.0-py3-none-any.whl.metadata (12 kB)
# Collecting jinja2 (from torch>=1.4->timm==0.5.4->nougat-ocr)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->sconf>=0.2.3->nougat-ocr)
#   Using cached ruamel.yaml.clib-0.2.8-cp312-cp312-macosx_13_0_arm64.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.4->timm==0.5.4->nougat-ocr)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.4->timm==0.5.4->nougat-ocr)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached uniflow-0.0.31-py3-none-any.whl (93 kB)
# Using cached nougat_ocr-0.1.17-py3-none-any.whl (82 kB)
# Using cached timm-0.5.4-py3-none-any.whl (431 kB)
# Using cached transformers-4.42.3-py3-none-any.whl (9.3 MB)
# Using cached datasets-2.20.0-py3-none-any.whl (547 kB)
# Using cached albumentations-1.4.11-py3-none-any.whl (165 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached aiohttp-3.9.5-cp312-cp312-macosx_11_0_arm64.whl (392 kB)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Using cached lightning-2.3.3-py3-none-any.whl (808 kB)
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 19.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading openai-1.35.11-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.4/328.4 kB 18.2 MB/s eta 0:00:00
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
# Using cached pyarrow-16.1.0-cp312-cp312-macosx_11_0_arm64.whl (26.0 MB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pypdf-4.2.0-py3-none-any.whl (290 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl (165 kB)
# Using cached regex-2024.5.15-cp312-cp312-macosx_11_0_arm64.whl (278 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached safetensors-0.4.3-cp312-cp312-macosx_11_0_arm64.whl (411 kB)
# Using cached sconf-0.2.5-py3-none-any.whl (8.8 kB)
# Using cached tiktoken-0.6.0-cp312-cp312-macosx_11_0_arm64.whl (922 kB)
# Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Using cached orjson-3.10.6-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
# Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached pypdfium2-4.30.0-py3-none-macosx_11_0_arm64.whl (2.7 MB)
# Using cached python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Using cached Levenshtein-0.25.1-cp312-cp312-macosx_11_0_arm64.whl (103 kB)
# Using cached sentencepiece-0.2.0-cp312-cp312-macosx_11_0_arm64.whl (1.2 MB)
# Using cached xxhash-3.4.1-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached albucore-0.0.12-py3-none-any.whl (8.4 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached lightning_utilities-0.11.3.post0-py3-none-any.whl (26 kB)
# Using cached multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached scikit_image-0.24.0-cp312-cp312-macosx_12_0_arm64.whl (13.4 MB)
# Using cached scikit_learn-1.5.1-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading torch-2.3.1-cp312-none-macosx_11_0_arm64.whl (61.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 MB 20.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Using cached munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Using cached pytorch_lightning-2.3.3-py3-none-any.whl (812 kB)
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Downloading torchvision-0.18.1-cp312-cp312-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.4 MB/s eta 0:00:0031m30.6 MB/s eta 0:00:01
# Using cached imageio-2.34.2-py3-none-any.whl (313 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached rapidfuzz-3.9.4-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
# Using cached ruamel.yaml.clib-0.2.8-cp312-cp312-macosx_13_0_arm64.whl (135 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tifffile-2024.7.2-py3-none-any.whl (225 kB)
# Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached sympy-1.13.0-py3-none-any.whl (6.2 MB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl (18 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: sentencepiece, pytz, mpmath, xxhash, urllib3, tzdata, typing-extensions, tqdm, tomli, threadpoolctl, sympy, sniffio, safetensors, ruamel.yaml.clib, regex, rapidfuzz, pyyaml, python-dotenv, pypdfium2, pypdf, pyarrow-hotfix, Pillow, orjson, numpy, networkx, munch, multidict, MarkupSafe, lazy-loader, joblib, idna, h11, graphviz, fsspec, frozenlist, filelock, eval-type-backport, distro, dill, click, charset-normalizer, certifi, attrs, annotated-types, yarl, tifffile, scipy, ruamel.yaml, requests, pydantic-core, pyarrow, pandas, opencv-python-headless, nltk, multiprocess, lightning-utilities, Levenshtein, jinja2, imageio, httpcore, anyio, aiosignal, torch, tiktoken, sconf, scikit-learn, scikit-image, python-Levenshtein, pydantic, huggingface-hub, httpx, albucore, aiohttp, torchvision, torchmetrics, tokenizers, openai, albumentations, uniflow, transformers, timm, pytorch-lightning, datasets, lightning, nougat-ocr
# Successfully installed Levenshtein-0.25.1 MarkupSafe-2.1.5 Pillow-10.4.0 aiohttp-3.9.5 aiosignal-1.3.1 albucore-0.0.12 albumentations-1.4.11 annotated-types-0.7.0 anyio-4.4.0 attrs-23.2.0 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 datasets-2.20.0 dill-0.3.8 distro-1.9.0 eval-type-backport-0.2.0 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.5.0 graphviz-0.20.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.4 idna-3.7 imageio-2.34.2 jinja2-3.1.4 joblib-1.4.2 lazy-loader-0.4 lightning-2.3.3 lightning-utilities-0.11.3.post0 mpmath-1.3.0 multidict-6.0.5 multiprocess-0.70.16 munch-4.0.0 networkx-3.3 nltk-3.8.1 nougat-ocr-0.1.17 numpy-1.26.4 openai-1.35.11 opencv-python-headless-4.10.0.84 orjson-3.10.6 pandas-2.2.2 pyarrow-16.1.0 pyarrow-hotfix-0.6 pydantic-2.8.2 pydantic-core-2.20.1 pypdf-4.2.0 pypdfium2-4.30.0 python-Levenshtein-0.25.1 python-dotenv-1.0.1 pytorch-lightning-2.3.3 pytz-2024.1 pyyaml-6.0.1 rapidfuzz-3.9.4 regex-2024.5.15 requests-2.32.3 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 safetensors-0.4.3 scikit-image-0.24.0 scikit-learn-1.5.1 scipy-1.14.0 sconf-0.2.5 sentencepiece-0.2.0 sniffio-1.3.1 sympy-1.13.0 threadpoolctl-3.5.0 tifffile-2024.7.2 tiktoken-0.6.0 timm-0.5.4 tokenizers-0.19.1 tomli-2.0.1 torch-2.3.1 torchmetrics-1.4.0.post0 torchvision-0.18.1 tqdm-4.66.4 transformers-4.42.3 typing-extensions-4.12.2 tzdata-2024.1 uniflow-0.0.31 urllib3-2.2.2 xxhash-3.4.1 yarl-1.9.4

# %%
# !nougat data/fibra-shop-1T24.pdf --out output --batchsize=1
# !nougat data/fmty-1T24.pdf --out output --batchsize=1
# Out:
# /opt/miniconda3/envs/extractor/lib/python3.12/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|                                                    | 0/14 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/extractor/bin/nougat", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/miniconda3/envs/extractor/lib/python3.12/site-packages/predict.py", line 167, in main
#     model_output = model.inference(
#                    ^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/extractor/lib/python3.12/site-packages/nougat/model.py", line 592, in inference
#     decoder_output = self.decoder.model.generate(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/extractor/lib/python3.12/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/extractor/lib/python3.12/site-packages/transformers/generation/utils.py", line 1664, in generate
#     self._prepare_special_tokens(generation_config, kwargs_has_attention_mask, device=device)
#   File "/opt/miniconda3/envs/extractor/lib/python3.12/site-packages/transformers/generation/utils.py", line 1513, in _prepare_special_tokens
#     if eos_token_id is not None and torch.isin(elements=eos_token_id, test_elements=pad_token_id).any():
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# NotImplementedError: The operator 'aten::isin.Tensor_Tensor_out' is not currently implemented for the MPS device. If you want this op to be added in priority during the prototype phase of this feature, please comment on https://github.com/pytorch/pytorch/issues/77764. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# -> Cannot close object, library is destroyed. This may cause a memory leak!

# %%
import os
from uniflow.op.extract.split.splitter_factory import SplitterOpsFactory

# from huggingface_hub import hf_hub_download
# import re
# from PIL import Image
# from transformers import NougatProcessor, VisionEncoderDecoderModel
# from datasets import load_dataset
# import torch

# %% [markdown]
# display.clear_output()

# %%
dir_cur = os.getcwd()
pdf_file = "nike-paper.pdf"
input_file = os.path.join(f"{dir_cur}/data/", pdf_file)

# %%
SplitterOpsFactory.list()
